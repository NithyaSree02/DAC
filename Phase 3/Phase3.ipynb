# %%
import pandas as pd

# %%
data = pd.read_csv('statsfinal.csv')

# %%
display(data)
# Out:
#       Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0              0  13-06-2010  5422  3725   576   907  17187.74  23616.50
# 1              1  14-06-2010  7047   779  3578  1574  22338.99   4938.86
# 2              2  15-06-2010  1572  2082   595  1145   4983.24  13199.88
# 3              3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66
# 4              4  17-06-2010  3668  3207  2184   708  11627.56  20332.38
# ...          ...         ...   ...   ...   ...   ...       ...       ...
# 4595        4595  30-01-2023  2476  3419   525  1359   7848.92  21676.46
# 4596        4596  31-01-2023  7446   841  4825  1311  23603.82   5331.94
# 4597        4597  01-02-2023  6289  3143  3588   474  19936.13  19926.62
# 4598        4598  02-02-2023  3122  1188  5899   517   9896.74   7531.92
# 4599        4599  03-02-2023  1234  3854  2321   406   3911.78  24434.36
#
#           S-P3      S-P4
# 0      3121.92   6466.91
# 1     19392.76  11222.62
# ...

# %%
data.dropna(inplace=True)

# %%
data.fillna(0, inplace=True)

# %%
data.drop_duplicates(inplace=True)

# %%
data.to_csv('cleaned_data.csv', index=False)

# %%
display(data)
# Out:
#       Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0              0  13-06-2010  5422  3725   576   907  17187.74  23616.50
# 1              1  14-06-2010  7047   779  3578  1574  22338.99   4938.86
# 2              2  15-06-2010  1572  2082   595  1145   4983.24  13199.88
# 3              3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66
# 4              4  17-06-2010  3668  3207  2184   708  11627.56  20332.38
# ...          ...         ...   ...   ...   ...   ...       ...       ...
# 4595        4595  30-01-2023  2476  3419   525  1359   7848.92  21676.46
# 4596        4596  31-01-2023  7446   841  4825  1311  23603.82   5331.94
# 4597        4597  01-02-2023  6289  3143  3588   474  19936.13  19926.62
# 4598        4598  02-02-2023  3122  1188  5899   517   9896.74   7531.92
# 4599        4599  03-02-2023  1234  3854  2321   406   3911.78  24434.36
#
#           S-P3      S-P4
# 0      3121.92   6466.91
# 1     19392.76  11222.62
# ...

# %%
# Extract year from the 'Day' 'Month' 'year' from the 'Date' column using a lambda function
# We need to get the year from the data to analyse sales year to year
data['Day'] = data['Date'].apply(lambda x: x.split('-')[0])
data['Month'] = data['Date'].apply(lambda x: x.split('-')[1])
data['Year'] = data['Date'].apply(lambda x: x.split('-')[2])
data
# Out:
#             Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2      S-P3  \
# 0     13-06-2010  5422  3725   576   907  17187.74  23616.50   3121.92
# 1     14-06-2010  7047   779  3578  1574  22338.99   4938.86  19392.76
# 2     15-06-2010  1572  2082   595  1145   4983.24  13199.88   3224.90
# 3     16-06-2010  5657  2399  3140  1672  17932.69  15209.66  17018.80
# 4     17-06-2010  3668  3207  2184   708  11627.56  20332.38  11837.28
# ...          ...   ...   ...   ...   ...       ...       ...       ...
# 4595  30-01-2023  2476  3419   525  1359   7848.92  21676.46   2845.50
# 4596  31-01-2023  7446   841  4825  1311  23603.82   5331.94  26151.50
# 4597  01-02-2023  6289  3143  3588   474  19936.13  19926.62  19446.96
# 4598  02-02-2023  3122  1188  5899   517   9896.74   7531.92  31972.58
# 4599  03-02-2023  1234  3854  2321   406   3911.78  24434.36  12579.82
#
#           S-P4 Day Month  Year
# 0      6466.91  13    06  2010
# 1     11222.62  14    06  2010
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.display.max_columns=50
sns.set(style="darkgrid")

# %%
data.head(5)
# Out:
#          Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2      S-P3      S-P4  \
# 0  13-06-2010  5422  3725   576   907  17187.74  23616.50   3121.92   6466.91
# 1  14-06-2010  7047   779  3578  1574  22338.99   4938.86  19392.76  11222.62
# 2  15-06-2010  1572  2082   595  1145   4983.24  13199.88   3224.90   8163.85
# 3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66  17018.80  11921.36
# 4  17-06-2010  3668  3207  2184   708  11627.56  20332.38  11837.28   5048.04
#
#   Day Month  Year
# 0  13    06  2010
# 1  14    06  2010
# 2  15    06  2010
# 3  16    06  2010
# 4  17    06  2010

# %%
# Fethcing rows and columns
data.shape
# Out:
# (4600, 12)

# %%
# fetching column names
data.columns
# Out:
# Index(['Date', 'Q-P1', 'Q-P2', 'Q-P3', 'Q-P4', 'S-P1', 'S-P2', 'S-P3', 'S-P4',
#        'Day', 'Month', 'Year'],
#       dtype='object')

# %%
# basic info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4600 non-null   object
#  1   Q-P1    4600 non-null   int64
#  2   Q-P2    4600 non-null   int64
#  3   Q-P3    4600 non-null   int64
#  4   Q-P4    4600 non-null   int64
#  5   S-P1    4600 non-null   float64
#  6   S-P2    4600 non-null   float64
#  7   S-P3    4600 non-null   float64
#  8   S-P4    4600 non-null   float64
#  9   Day     4600 non-null   object
#  10  Month   4600 non-null   object
#  11  Year    4600 non-null   object
# dtypes: float64(4), int64(4), object(4)
# memory usage: 431.4+ KB

# %%
# Checking null values
data.isnull().sum()
# Out:
# Date     0
# Q-P1     0
# Q-P2     0
# Q-P3     0
# Q-P4     0
# S-P1     0
# S-P2     0
# S-P3     0
# S-P4     0
# Day      0
# Month    0
# Year     0
# dtype: int64

# %%
# Checking Dtypes
data.dtypes
# Out:
# Date      object
# Q-P1       int64
# Q-P2       int64
# Q-P3       int64
# Q-P4       int64
# S-P1     float64
# S-P2     float64
# S-P3     float64
# S-P4     float64
# Day       object
# Month     object
# Year      object
# dtype: object

# %%
data.duplicated().sum()
# Out:
# 0

# %%
## Basic statistical info
data.describe().T
# Out:
#        count          mean          std      min       25%        50%  \
# Q-P1  4600.0   4121.849130  2244.271323   254.00  2150.500   4137.000
# Q-P2  4600.0   2130.281522  1089.783705   251.00  1167.750   2134.000
# Q-P3  4600.0   3145.740000  1671.832231   250.00  1695.750   3202.500
# Q-P4  4600.0   1123.500000   497.385676   250.00   696.000   1136.500
# S-P1  4600.0  13066.261743  7114.340094   805.18  6817.085  13114.290
# S-P2  4600.0  13505.984848  6909.228687  1591.34  7403.535  13529.560
# S-P3  4600.0  17049.910800  9061.330694  1355.00  9190.965  17357.550
# S-P4  4600.0   8010.555000  3546.359869  1782.50  4962.480   8103.245
#
#             75%       max
# Q-P1   6072.000   7998.00
# Q-P2   3070.250   3998.00
# Q-P3   4569.000   6000.00
# Q-P4   1544.000   2000.00
# S-P1  19248.240  25353.66
# S-P2  19465.385  25347.32
# S-P3  24763.980  32520.00
# S-P4  11008.720  14260.00

# %%
data.sample(2)
# Out:
#             Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2      S-P3  \
# 1628  03-12-2014  4261   844   600   434  13507.37   5350.96   3252.00
# 49    01-08-2010  2062  3659  2194   803   6536.54  23198.06  11891.48
#
#          S-P4 Day Month  Year
# 1628  3094.42  03    12  2014
# 49    5725.39  01    08  2010

# %%
# Changing dtype 
from datetime import datetime as dt
data[data["Date"]=="31-9-2010"]
# Out:
#           Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1     S-P2      S-P3     S-P4  \
# 109  31-9-2010  4986   342  4978   558  15805.62  2168.28  26980.76  3978.54
#
#     Day Month  Year
# 109  31     9  2010

# %%
data['Date'] = pd.to_datetime(data['Date'], errors='coerce')

# %%
data[data['Date'].isnull()]
# Out:
#      Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2      S-P3      S-P4 Day  \
# 109   NaT  4986   342  4978   558  15805.62   2168.28  26980.76   3978.54  31
# 170   NaT  4632  3930   523  1581  14683.44  24916.20   2834.66  11272.53  31
# 473   NaT  2242   401  5926   789   7107.14   2542.34  32118.92   5625.57  31
# 534   NaT   325  3476  4588  1771   1030.25  22037.84  24866.96  12627.23  31
# 836   NaT  1003   256  1346  1449   3179.51   1623.04   7295.32  10331.37  31
# 897   NaT  2509  2666  4146   593   7953.53  16902.44  22471.32   4228.09  31
# 1200  NaT   597   709  5470  1994   1892.49   4495.06  29647.40  14217.22  31
# 1261  NaT  7681  1235   347  1087  24348.77   7829.90   1880.74   7750.31  31
# 1564  NaT  5333   833  3494   618  16905.61   5281.22  18937.48   4406.34  31
# 1625  NaT  3870  2779  3246  1290  12267.90  17618.86  17593.32   9197.70  31
# 1928  NaT  3583  2111  4225  1401  11358.11  13383.74  22899.50   9989.13  31
# ...

# %%
## Filling the NaT  values with average of time
data["Date"].fillna(data["Date"].mean(),inplace=True)

# %%
data['Date'].isnull().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# Date     datetime64[ns]
# Q-P1              int64
# Q-P2              int64
# Q-P3              int64
# Q-P4              int64
# S-P1            float64
# S-P2            float64
# S-P3            float64
# S-P4            float64
# Day              object
# Month            object
# Year             object
# dtype: object

# %%
#fetching weekday
data["dayoftheweek"]=data["Date"].dt.weekday
data.sample()
# Out:
#            Date  Q-P1  Q-P2  Q-P3  Q-P4     S-P1      S-P2     S-P3      S-P4  \
# 1352 2014-03-02  2357  3234  1781  1716  7471.69  20503.56  9653.02  12235.08
#
#      Day Month  Year  dayoftheweek
# 1352  02    03  2014             6

# %%
data.corr().T
# Out:
#                   Date      Q-P1      Q-P2      Q-P3      Q-P4      S-P1  \
# Date          1.000000 -0.001607  0.007008  0.004984 -0.008926 -0.001607
# Q-P1         -0.001607  1.000000  0.002422 -0.005650 -0.059365  1.000000
# Q-P2          0.007008  0.002422  1.000000  0.003729  0.013082  0.002422
# Q-P3          0.004984 -0.005650  0.003729  1.000000 -0.006693 -0.005650
# Q-P4         -0.008926 -0.059365  0.013082 -0.006693  1.000000 -0.059365
# S-P1         -0.001607  1.000000  0.002422 -0.005650 -0.059365  1.000000
# S-P2          0.007008  0.002422  1.000000  0.003729  0.013082  0.002422
# S-P3          0.004984 -0.005650  0.003729  1.000000 -0.006693 -0.005650
# S-P4         -0.008926 -0.059365  0.013082 -0.006693  1.000000 -0.059365
# Day           0.000672 -0.000912 -0.010996 -0.028226  0.014732 -0.000912
# Month        -0.000456 -0.009342 -0.017790 -0.006541  0.005417 -0.009342
# Year          0.993923 -0.000381  0.010162  0.005943 -0.010227 -0.000381
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
for i in data.columns:
    print(i,"---------",data[i].unique())
# Out:
# Date --------- <DatetimeArray>
# ['2010-06-13 00:00:00', '2010-06-14 00:00:00', '2010-06-15 00:00:00',
#  '2010-06-16 00:00:00', '2010-06-17 00:00:00', '2010-06-18 00:00:00',
#  '2010-06-19 00:00:00', '2010-06-20 00:00:00', '2010-06-21 00:00:00',
#  '2010-06-22 00:00:00',
#  ...
#  '2023-01-25 00:00:00', '2023-01-26 00:00:00', '2023-01-27 00:00:00',
#  '2023-01-28 00:00:00', '2023-01-29 00:00:00', '2023-01-30 00:00:00',
#  '2023-01-31 00:00:00', '2023-02-01 00:00:00', '2023-02-02 00:00:00',
#  '2023-02-03 00:00:00']
# Length: 4575, dtype: datetime64[ns]
# Q-P1 --------- [5422 7047 1572 ... 1227 3122 1234]
# Q-P2 --------- [3725  779 2082 ... 3404  841 3143]
# Q-P3 --------- [ 576 3578  595 ... 4825 3588 5899]
# Q-P4 --------- [ 907 1574 1145 ... 1161 1151 1112]
# S-P1 --------- [17187.74 22338.99  4983.24 ...  3889.59  9896.74  3911.78]
# S-P2 --------- [23616.5   4938.86 13199.88 ... 21581.36  5331.94 19926.62]
# ...

# %%
# Total unit sales Product 1, Product 2, Product 3, Product 4 
q = data[["Q-P1","Q-P2","Q-P3","Q-P4"]].sum()
print(q)
plt.figure(figsize=(8,8))
plt.pie(q,labels=data[["Q-P1","Q-P2","Q-P3","Q-P4"]].sum().index,shadow=True,autopct="%0.01f%%",textprops={"fontsize":20},wedgeprops={'width': 0.8},explode=[0,0,0,0.3])
plt.legend(loc='center right', bbox_to_anchor=(1.2, 0.8));
# Out:
# Q-P1    18960506
# Q-P2     9799295
# Q-P3    14470404
# Q-P4     5168100
# dtype: int64

# %%
# Total Revenue percent from sales from Product 1, Product 2, Product 3, Product 4  
s=data[["S-P1","S-P2","S-P3","S-P4"]].sum()
print(s)
plt.figure(figsize=(8,8))
plt.pie(s,labels=data[["S-P1","S-P2","S-P3","S-P4"]].sum().index,shadow=True,autopct="%0.01f%%",textprops={"fontsize":20},wedgeprops={'width': 0.8},explode=[0,0,0,0.3])
plt.legend(loc='center right', bbox_to_anchor=(1.2, 0.8))
# Out:
# S-P1    60104804.02
# S-P2    62127530.30
# S-P3    78429589.68
# S-P4    36848553.00
# dtype: float64

# %%
# which is the most occuring month 
print(data["Month"].value_counts())
plt.figure(figsize=(10,10))
sns.countplot(x="Month",data=data,edgecolor="black")
plt.xticks(rotation=90);
# Out:
# Month
# 07    403
# 11    403
# 01    403
# 08    390
# 09    390
# 10    390
# 12    390
# 06    378
# 03    372
# 05    372
# 04    360
# 02    336
# 9      13
# Name: count, dtype: int64

# %%
# which is the most occuring Day 
print(data["Day"].value_counts())
plt.figure(figsize=(10,10))
sns.countplot(x="Day",data=data,edgecolor="black")
plt.xticks(rotation=90);
# Out:
# Day
# 13    152
# 23    152
# 03    152
# 02    152
# 01    152
# 14    152
# 27    152
# 25    152
# 24    152
# 26    152
# 22    152
# 18    152
# 15    152
# 16    152
# 21    152
# 17    152
# 19    152
# 20    152
# 12    151
# 11    151
# 10    151
# 04    151
# 05    151
# 06    151
# 07    151
# 08    151
# 09    151
# 28    149
# 29    140
# 30    127
# 31     89
# Name: count, dtype: int64

# %%
# which is the most occuring year 
print(data["Year"].value_counts())
plt.figure(figsize=(10,10))
sns.countplot(x="Year",data=data,edgecolor="black")
plt.xticks(rotation=90);
# Out:
# Year
# 2011    364
# 2013    364
# 2014    364
# 2015    364
# 2017    364
# 2018    364
# 2019    364
# 2021    364
# 2022    364
# 2012    363
# 2016    363
# 2020    363
# 2010    201
# 2023     34
# Name: count, dtype: int64
