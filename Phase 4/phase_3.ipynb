# %%
import pandas as pd

# %%
data = pd.read_csv('statsfinal.csv')

# %%
display(data)
# Out:
#       Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0              0  13-06-2010  5422  3725   576   907  17187.74  23616.50
# 1              1  14-06-2010  7047   779  3578  1574  22338.99   4938.86
# 2              2  15-06-2010  1572  2082   595  1145   4983.24  13199.88
# 3              3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66
# 4              4  17-06-2010  3668  3207  2184   708  11627.56  20332.38
# ...          ...         ...   ...   ...   ...   ...       ...       ...
# 4595        4595  30-01-2023  2476  3419   525  1359   7848.92  21676.46
# 4596        4596  31-01-2023  7446   841  4825  1311  23603.82   5331.94
# 4597        4597  01-02-2023  6289  3143  3588   474  19936.13  19926.62
# 4598        4598  02-02-2023  3122  1188  5899   517   9896.74   7531.92
# 4599        4599  03-02-2023  1234  3854  2321   406   3911.78  24434.36
#
#           S-P3      S-P4
# 0      3121.92   6466.91
# 1     19392.76  11222.62
# ...

# %%
data.dropna(inplace=True)

# %%
data.fillna(0, inplace=True)

# %%
data.drop_duplicates(inplace=True)

# %%
data.to_csv('cleaned_data.csv', index=False)

# %%
display(data)
# Out:
#       Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0              0  13-06-2010  5422  3725   576   907  17187.74  23616.50
# 1              1  14-06-2010  7047   779  3578  1574  22338.99   4938.86
# 2              2  15-06-2010  1572  2082   595  1145   4983.24  13199.88
# 3              3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66
# 4              4  17-06-2010  3668  3207  2184   708  11627.56  20332.38
# ...          ...         ...   ...   ...   ...   ...       ...       ...
# 4595        4595  30-01-2023  2476  3419   525  1359   7848.92  21676.46
# 4596        4596  31-01-2023  7446   841  4825  1311  23603.82   5331.94
# 4597        4597  01-02-2023  6289  3143  3588   474  19936.13  19926.62
# 4598        4598  02-02-2023  3122  1188  5899   517   9896.74   7531.92
# 4599        4599  03-02-2023  1234  3854  2321   406   3911.78  24434.36
#
#           S-P3      S-P4
# 0      3121.92   6466.91
# 1     19392.76  11222.62
# ...

# %%
# Extract year from the 'Day' 'Month' 'year' from the 'Date' column using a lambda function
# We need to get the year from the data to analyse sales year to year
data['Day'] = data['Date'].apply(lambda x: x.split('-')[0])
data['Month'] = data['Date'].apply(lambda x: x.split('-')[1])
data['Year'] = data['Date'].apply(lambda x: x.split('-')[2])
data
# Out:
#       Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0              0  13-06-2010  5422  3725   576   907  17187.74  23616.50
# 1              1  14-06-2010  7047   779  3578  1574  22338.99   4938.86
# 2              2  15-06-2010  1572  2082   595  1145   4983.24  13199.88
# 3              3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66
# 4              4  17-06-2010  3668  3207  2184   708  11627.56  20332.38
# ...          ...         ...   ...   ...   ...   ...       ...       ...
# 4595        4595  30-01-2023  2476  3419   525  1359   7848.92  21676.46
# 4596        4596  31-01-2023  7446   841  4825  1311  23603.82   5331.94
# 4597        4597  01-02-2023  6289  3143  3588   474  19936.13  19926.62
# 4598        4598  02-02-2023  3122  1188  5899   517   9896.74   7531.92
# 4599        4599  03-02-2023  1234  3854  2321   406   3911.78  24434.36
#
#           S-P3      S-P4 Day Month  Year
# 0      3121.92   6466.91  13    06  2010
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.display.max_columns=50
sns.set(style="darkgrid")

# %%
data.head(5)
# Out:
#    Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0           0  13-06-2010  5422  3725   576   907  17187.74  23616.50
# 1           1  14-06-2010  7047   779  3578  1574  22338.99   4938.86
# 2           2  15-06-2010  1572  2082   595  1145   4983.24  13199.88
# 3           3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66
# 4           4  17-06-2010  3668  3207  2184   708  11627.56  20332.38
#
#        S-P3      S-P4 Day Month  Year
# 0   3121.92   6466.91  13    06  2010
# 1  19392.76  11222.62  14    06  2010
# 2   3224.90   8163.85  15    06  2010
# 3  17018.80  11921.36  16    06  2010
# 4  11837.28   5048.04  17    06  2010

# %%
# Fethcing rows and columns
data.shape
# Out:
# (4600, 13)

# %%
# fetching column names
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Q-P1', 'Q-P2', 'Q-P3', 'Q-P4', 'S-P1', 'S-P2',
#        'S-P3', 'S-P4', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
# basic info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4600 non-null   int64
#  1   Date        4600 non-null   object
#  2   Q-P1        4600 non-null   int64
#  3   Q-P2        4600 non-null   int64
#  4   Q-P3        4600 non-null   int64
#  5   Q-P4        4600 non-null   int64
#  6   S-P1        4600 non-null   float64
#  7   S-P2        4600 non-null   float64
#  8   S-P3        4600 non-null   float64
#  9   S-P4        4600 non-null   float64
#  10  Day         4600 non-null   object
#  11  Month       4600 non-null   object
#  12  Year        4600 non-null   object
# dtypes: float64(4), int64(5), object(4)
# memory usage: 467.3+ KB

# %%
# Checking null values
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Date          0
# Q-P1          0
# Q-P2          0
# Q-P3          0
# Q-P4          0
# S-P1          0
# S-P2          0
# S-P3          0
# S-P4          0
# Day           0
# Month         0
# Year          0
# dtype: int64

# %%
# Checking Dtypes
data.dtypes
# Out:
# Unnamed: 0      int64
# Date           object
# Q-P1            int64
# Q-P2            int64
# Q-P3            int64
# Q-P4            int64
# S-P1          float64
# S-P2          float64
# S-P3          float64
# S-P4          float64
# Day            object
# Month          object
# Year           object
# dtype: object

# %%
data.duplicated().sum()
# Out:
# 0

# %%
## Basic statistical info
data.describe().T
# Out:
#              count          mean          std      min       25%        50%  \
# Unnamed: 0  4600.0   2299.500000  1328.049949     0.00  1149.750   2299.500
# Q-P1        4600.0   4121.849130  2244.271323   254.00  2150.500   4137.000
# Q-P2        4600.0   2130.281522  1089.783705   251.00  1167.750   2134.000
# Q-P3        4600.0   3145.740000  1671.832231   250.00  1695.750   3202.500
# Q-P4        4600.0   1123.500000   497.385676   250.00   696.000   1136.500
# S-P1        4600.0  13066.261743  7114.340094   805.18  6817.085  13114.290
# S-P2        4600.0  13505.984848  6909.228687  1591.34  7403.535  13529.560
# S-P3        4600.0  17049.910800  9061.330694  1355.00  9190.965  17357.550
# S-P4        4600.0   8010.555000  3546.359869  1782.50  4962.480   8103.245
#
#                   75%       max
# Unnamed: 0   3449.250   4599.00
# Q-P1         6072.000   7998.00
# Q-P2         3070.250   3998.00
# Q-P3         4569.000   6000.00
# Q-P4         1544.000   2000.00
# ...

# %%
data.sample(2)
# Out:
#       Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 644          644  22-03-2012  4471   612  5155  1260  14173.07   3880.08
# 2212        2212  13-07-2016  5397  2715   802  1526  17108.49  17213.10
#
#           S-P3      S-P4 Day Month  Year
# 644   27940.10   8983.80  22    03  2012
# 2212   4346.84  10880.38  13    07  2016

# %%
# Changing dtype 
from datetime import datetime as dt
data[data["Date"]=="31-9-2010"]
# Out:
#      Unnamed: 0       Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1     S-P2  \
# 109         109  31-9-2010  4986   342  4978   558  15805.62  2168.28
#
#          S-P3     S-P4 Day Month  Year
# 109  26980.76  3978.54  31     9  2010

# %%
data['Date'] = pd.to_datetime(data['Date'], errors='coerce')
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_27684\3064529874.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['Date'] = pd.to_datetime(data['Date'], errors='coerce')

# %%
data[data['Date'].isnull()]
# Out:
#       Unnamed: 0 Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2      S-P3  \
# 109          109  NaT  4986   342  4978   558  15805.62   2168.28  26980.76
# 170          170  NaT  4632  3930   523  1581  14683.44  24916.20   2834.66
# 473          473  NaT  2242   401  5926   789   7107.14   2542.34  32118.92
# 534          534  NaT   325  3476  4588  1771   1030.25  22037.84  24866.96
# 836          836  NaT  1003   256  1346  1449   3179.51   1623.04   7295.32
# 897          897  NaT  2509  2666  4146   593   7953.53  16902.44  22471.32
# 1200        1200  NaT   597   709  5470  1994   1892.49   4495.06  29647.40
# 1261        1261  NaT  7681  1235   347  1087  24348.77   7829.90   1880.74
# 1564        1564  NaT  5333   833  3494   618  16905.61   5281.22  18937.48
# 1625        1625  NaT  3870  2779  3246  1290  12267.90  17618.86  17593.32
# 1928        1928  NaT  3583  2111  4225  1401  11358.11  13383.74  22899.50
# ...

# %%
## Filling the NaT  values with average of time
data["Date"].fillna(data["Date"].mean(),inplace=True)

# %%
data['Date'].isnull().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# Unnamed: 0             int64
# Date          datetime64[ns]
# Q-P1                   int64
# Q-P2                   int64
# Q-P3                   int64
# Q-P4                   int64
# S-P1                 float64
# S-P2                 float64
# S-P3                 float64
# S-P4                 float64
# Day                   object
# Month                 object
# Year                  object
# dtype: object

# %%
#fetching weekday
data["dayoftheweek"]=data["Date"].dt.weekday
data.sample()
# Out:
#      Unnamed: 0       Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 774         774 2012-07-30  5229  2789  2507  1177  16575.93  17682.26
#
#          S-P3     S-P4 Day Month  Year  dayoftheweek
# 774  13587.94  8392.01  30    07  2012           0.0

# %%
data.corr().T
# Out:
#               Unnamed: 0      Date      Q-P1      Q-P2      Q-P3      Q-P4  \
# Unnamed: 0      1.000000  0.140080 -0.001120  0.008716  0.005255 -0.009739
# Date            0.140080  1.000000  0.008510 -0.005952 -0.014768  0.005026
# Q-P1           -0.001120  0.008510  1.000000  0.002422 -0.005650 -0.059365
# Q-P2            0.008716 -0.005952  0.002422  1.000000  0.003729  0.013082
# Q-P3            0.005255 -0.014768 -0.005650  0.003729  1.000000 -0.006693
# Q-P4           -0.009739  0.005026 -0.059365  0.013082 -0.006693  1.000000
# S-P1           -0.001120  0.008510  1.000000  0.002422 -0.005650 -0.059365
# S-P2            0.008716 -0.005952  0.002422  1.000000  0.003729  0.013082
# S-P3            0.005255 -0.014768 -0.005650  0.003729  1.000000 -0.006693
# S-P4           -0.009739  0.005026 -0.059365  0.013082 -0.006693  1.000000
# Day             0.000858 -0.130071 -0.000912 -0.010996 -0.028226  0.014732
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
for i in data.columns:
    print(i,"---------",data[i].unique())
# Out:
# Unnamed: 0 --------- [   0    1    2 ... 4597 4598 4599]
# Date --------- <DatetimeArray>
# ['2010-06-13 00:00:00', '2010-06-14 00:00:00', '2010-06-15 00:00:00',
#  '2010-06-16 00:00:00', '2010-06-17 00:00:00', '2010-06-18 00:00:00',
#  '2010-06-19 00:00:00', '2010-06-20 00:00:00', '2010-06-21 00:00:00',
#  '2010-06-22 00:00:00',
#  ...
#  '2023-01-25 00:00:00', '2023-01-26 00:00:00', '2023-01-27 00:00:00',
#  '2023-01-28 00:00:00', '2023-01-29 00:00:00', '2023-01-30 00:00:00',
#  '2023-01-31 00:00:00', '2023-02-01 00:00:00', '2023-02-02 00:00:00',
#  '2023-02-03 00:00:00']
# Length: 4575, dtype: datetime64[ns]
# Q-P1 --------- [5422 7047 1572 ... 1227 3122 1234]
# Q-P2 --------- [3725  779 2082 ... 3404  841 3143]
# Q-P3 --------- [ 576 3578  595 ... 4825 3588 5899]
# Q-P4 --------- [ 907 1574 1145 ... 1161 1151 1112]
# S-P1 --------- [17187.74 22338.99  4983.24 ...  3889.59  9896.74  3911.78]
# S-P2 --------- [23616.5   4938.86 13199.88 ... 21581.36  5331.94 19926.62]
# ...

# %%
# Total unit sales Product 1, Product 2, Product 3, Product 4 
q = data[["Q-P1","Q-P2","Q-P3","Q-P4"]].sum()
print(q)
plt.figure(figsize=(8,8))
plt.pie(q,labels=data[["Q-P1","Q-P2","Q-P3","Q-P4"]].sum().index,shadow=True,autopct="%0.01f%%",textprops={"fontsize":20},wedgeprops={'width': 0.8},explode=[0,0,0,0.3])
plt.legend(loc='center right', bbox_to_anchor=(1.2, 0.8));
# Out:
# Q-P1    18960506
# Q-P2     9799295
# Q-P3    14470404
# Q-P4     5168100
# dtype: int64

# %%
# Total Revenue percent from sales from Product 1, Product 2, Product 3, Product 4  
s=data[["S-P1","S-P2","S-P3","S-P4"]].sum()
print(s)
plt.figure(figsize=(8,8))
plt.pie(s,labels=data[["S-P1","S-P2","S-P3","S-P4"]].sum().index,shadow=True,autopct="%0.01f%%",textprops={"fontsize":20},wedgeprops={'width': 0.8},explode=[0,0,0,0.3])
plt.legend(loc='center right', bbox_to_anchor=(1.2, 0.8))
# Out:
# S-P1    60104804.02
# S-P2    62127530.30
# S-P3    78429589.68
# S-P4    36848553.00
# dtype: float64

# %%
# which is the most occuring month 
print(data["Month"].value_counts())
plt.figure(figsize=(10,10))
sns.countplot(x="Month",data=data,edgecolor="black")
plt.xticks(rotation=90);
# Out:
# Month
# 07    403
# 11    403
# 01    403
# 08    390
# 09    390
# 10    390
# 12    390
# 06    378
# 03    372
# 05    372
# 04    360
# 02    336
# 9      13
# Name: count, dtype: int64

# %%
# which is the most occuring Day 
print(data["Day"].value_counts())
plt.figure(figsize=(10,10))
sns.countplot(x="Day",data=data,edgecolor="black")
plt.xticks(rotation=90);
# Out:
# Day
# 13    152
# 23    152
# 03    152
# 02    152
# 01    152
# 14    152
# 27    152
# 25    152
# 24    152
# 26    152
# 22    152
# 18    152
# 15    152
# 16    152
# 21    152
# 17    152
# 19    152
# 20    152
# 12    151
# 11    151
# 10    151
# 04    151
# 05    151
# 06    151
# 07    151
# 08    151
# 09    151
# 28    149
# 29    140
# 30    127
# 31     89
# Name: count, dtype: int64

# %%
# which is the most occuring year 
print(data["Year"].value_counts())
plt.figure(figsize=(10,10))
sns.countplot(x="Year",data=data,edgecolor="black")
plt.xticks(rotation=90);
# Out:
# Year
# 2011    364
# 2013    364
# 2014    364
# 2015    364
# 2017    364
# 2018    364
# 2019    364
# 2021    364
# 2022    364
# 2012    363
# 2016    363
# 2020    363
# 2010    201
# 2023     34
# Name: count, dtype: int64

# %%
data["month"]=data["Date"].dt.month_name()

# %%
# Monthly distrubution of revenue 
sns.relplot(x="month",y="S-P1",data=data,kind="line",height=10,color="red")
plt.xticks(rotation=90);
sns.relplot(x="month",y="S-P2",data=data,kind="line",height=10,color="blue")
plt.xticks(rotation=90);
sns.relplot(x="month",y="S-P3",data=data,kind="line",height=10,color="green")
plt.xticks(rotation=90);
sns.relplot(x="month",y="S-P4",data=data,kind="line",height=10,color="purple")
plt.xticks(rotation=90);
# Out:
# c:\Users\91984\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\91984\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\91984\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\91984\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
## In which month revenue was it peak
data.groupby("month")[["S-P1","S-P2","S-P3","S-P4"]].sum()
# Out:
#                  S-P1        S-P2        S-P3        S-P4
# month
# April      4802375.65  4826870.24  6272544.32  2927620.78
# August     5032774.42  5518177.50  6628101.74  3137000.36
# December   5177646.59  5241931.02  6502103.00  3089200.84
# February   4487670.73  4486678.52  5796061.28  2629665.21
# January    5272626.13  5679403.70  6842229.68  3234973.69
# July       5426396.49  5228021.06  6618524.60  3262381.41
# June       5106248.68  5045340.30  6335204.94  3001309.33
# March      4775839.58  5154185.42  6111066.26  2982307.88
# May        4767692.68  5021875.96  6773238.50  2917653.04
# November   4959059.24  5183907.34  6668627.08  3147609.80
# October    5192694.58  5182607.64  6552210.90  3105264.73
# September  4785710.96  5190659.44  6837535.96  3213063.20

# %%
plt.figure(figsize=(15,15),dpi=100)
plt.subplot(2,2,1)
sns.barplot(x="month",y="S-P1",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,2)
sns.barplot(x="month",y="S-P2",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,3)
sns.barplot(x="month",y="S-P3",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,4)
sns.barplot(x="month",y="S-P4",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90)
plt.subplots_adjust(hspace=0.3);

# %%
data.sample()
# Out:
#       Unnamed: 0       Date  Q-P1  Q-P2  Q-P3  Q-P4     S-P1      S-P2  \
# 2322        2322 2016-11-01  3125  2582   406   648  9906.25  16369.88
#
#          S-P3     S-P4 Day Month  Year  dayoftheweek     month
# 2322  2200.52  4620.24  01    11  2016           1.0  November

# %%
## In which month unit sales were more in Product 1, Product 2, Product 3, Product 4 
data.groupby ("month")[["Q-P1","Q-P2","Q-P3","Q-P4"]].sum()
# Out:
#               Q-P1    Q-P2     Q-P3    Q-P4
# month
# April      1514945  761336  1157296  410606
# August     1587626  870375  1222897  439972
# December   1633327  826803  1199650  433268
# February   1415669  707678  1069384  368817
# January    1663289  895805  1262404  453713
# July       1711797  824609  1221130  457557
# June       1610804  795795  1168857  420941
# March      1506574  812963  1127503  418276
# May        1504004  792094  1249675  409208
# November   1564372  817651  1230374  441460
# October    1638074  817446  1208895  435521
# September  1509688  818716  1261538  450640

# %%
plt.figure(figsize=(15,15),dpi=100)
plt.subplot(2,2,1)
sns.barplot(x="month",y="Q-P1",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,2)
sns.barplot(x="month",y="Q-P2",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,3)
sns.barplot(x="month",y="Q-P3",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,4)
sns.barplot(x="month",y="Q-P4",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90)
plt.subplots_adjust(hspace=0.3);

# %%
data["day"]=data["Date"].dt.day_name()

# %%
week_t=data[data["dayoftheweek"]<5]
weekend_t=data[data["dayoftheweek"]>=5]
print(week_t.groupby("day")[["S-P1","S-P2","S-P3","S-P4"]].sum())
# Out:
#                  S-P1        S-P2         S-P3        S-P4
# day
# Friday     8838549.62  8898088.56  11056312.20  5142733.53
# Monday     8590452.74  8675681.36  11016047.02  5305654.03
# Thursday   8499752.70  9010725.00  10895462.86  5112751.88
# Tuesday    8458961.14  8590928.24  11084062.60  5253576.51
# Wednesday  8476478.56  8995331.48  11328873.16  5139403.82

# %%
plt.figure(figsize=(10,10),dpi=100)
plt.subplot(2,2,1)
sns.barplot(x="day",y="S-P1",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,2)
sns.barplot(x="day",y="S-P2",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,3)
sns.barplot(x="day",y="S-P3",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,4)
sns.barplot(x="day",y="S-P4",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45)
plt.subplots_adjust(hspace=0.5);

# %%
print(weekend_t.groupby("day")[["S-P1","S-P2","S-P3","S-P4"]].sum())
# Out:
#                 S-P1        S-P2         S-P3        S-P4
# day
# Saturday  8527781.84  8865500.96  11572057.72  5411691.39
# Sunday    8394759.13  8723402.54  10984632.70  5282239.11

# %%
plt.figure(figsize=(10,10),dpi=100)
plt.subplot(2,2,1)
sns.barplot(x="day",y="S-P1",data=weekend_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,2)
sns.barplot(x="day",y="S-P2",data=weekend_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,3)
sns.barplot(x="day",y="S-P3",data=weekend_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,4)
sns.barplot(x="day",y="S-P4",data=weekend_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45)
plt.subplots_adjust(hspace=0.5);

# %%
# In which year revenue was the highest 
data.groupby("Year")[["S-P1","S-P2","S-P3","S-P4"]].agg(["sum"])
# Out:
#             S-P1        S-P2        S-P3        S-P4
#              sum         sum         sum         sum
# Year
# 2010  2573948.07  2747185.40  3415277.50  1582774.44
# 2011  4550956.61  4765727.28  6292061.74  2939855.86
# 2012  4782296.87  4880512.98  6203677.80  2979769.60
# 2013  4859923.83  4783694.84  6049337.88  2890459.22
# 2014  4983696.48  5002697.46  6301936.98  2878723.24
# 2015  4704904.49  4868891.76  6027777.12  2946479.63
# 2016  4810801.51  4969875.28  6030823.16  2911998.95
# 2017  4658996.55  5128064.62  6323340.56  2987612.60
# 2018  4854598.23  4762937.68  6244219.40  2841661.50
# 2019  4699914.91  4979264.82  6153120.04  2926330.25
# 2020  4749791.69  4934561.48  6370001.34  2993559.02
# 2021  4770834.15  4986054.96  6323692.86  2904569.49
# 2022  4627657.93  4821633.40  6043760.70  2780093.95
# 2023   476482.70   496428.34   650562.60   284665.25

# %%
plt.figure(figsize=(10,10),dpi=100)
plt.subplot(2,2,1)
sns.barplot(x="Year",y="S-P1",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,2)
sns.barplot(x="Year",y="S-P2",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,3)
sns.barplot(x="Year",y="S-P3",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,4)
sns.barplot(x="Year",y="S-P4",data=data,edgecolor="black",estimator=sum)
plt.xticks(rotation=90)
plt.subplots_adjust(hspace=0.5);

# %%
## What was the avg revenue, maximum and min
data[["S-P1","S-P2","S-P3","S-P4"]].agg(["sum","max","min","mean"])
# Out:
#               S-P1          S-P2          S-P3          S-P4
# sum   6.010480e+07  6.212753e+07  7.842959e+07  3.684855e+07
# max   2.535366e+04  2.534732e+04  3.252000e+04  1.426000e+04
# min   8.051800e+02  1.591340e+03  1.355000e+03  1.782500e+03
# mean  1.306626e+04  1.350598e+04  1.704991e+04  8.010555e+03

# %%
plt.figure(figsize=(10,10),dpi=100)
plt.subplot(2,2,1)
sns.barplot(x="day",y="Q-P1",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,2)
sns.barplot(x="day",y="Q-P2",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,3)
sns.barplot(x="day",y="Q-P3",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,4)
sns.barplot(x="day",y="Q-P4",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45)
plt.subplots_adjust(hspace=0.5);

# %%
plt.figure(figsize=(10,10),dpi=100)
plt.subplot(2,2,1)
sns.barplot(x="day",y="Q-P1",data=weekend_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,2)
sns.barplot(x="day",y="Q-P2",data=weekend_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,3)
sns.barplot(x="day",y="Q-P3",data=weekend_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,4)
sns.barplot(x="day",y="Q-P4",data=weekend_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45)
plt.subplots_adjust(hspace=0.5);

# %%
# gives us the average for all the 31st days across all years for each product
def avg_on_31st(df, product):
    df_31 = df[df['Day'] == '31']
    avg_sales = df_31[product].mean()
    return avg_sales

# %%
# Average for Unit Sales
avg_on_31st(data, ['Q-P1', 'Q-P2', 'Q-P3', 'Q-P4']).round(2)
# Out:
# Q-P1    3850.73
# Q-P2    2076.51
# Q-P3    3196.45
# Q-P4    1112.13
# dtype: float64

# %%
# Average for Revenue
avg_on_31st(data, ['S-P1', 'S-P2', 'S-P3', 'S-P4']).round(2)
# Out:
# S-P1    12206.82
# S-P2    13165.05
# S-P3    17324.76
# S-P4     7929.52
# dtype: float64
